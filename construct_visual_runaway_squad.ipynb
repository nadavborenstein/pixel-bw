# %%
import wandb
from pixel_datasets.squad_dataset_for_pixel import SquadDatasetForPixel
from pixel_datasets.real_dataset import HistoricDatasetForPretraining
from pixel_datasets.dataset_transformations import (SimpleTorchTransform, SyntheticDatasetTransform)
from pixel_datasets.utils.squad_utils import convert_pixel_mask_to_patch_mask
from PIL import Image
import numpy as np
import datasets
from datasets import load_dataset, load_from_disk
import random
from glob import glob
import os

# %%
QUESTIONS = {
 "Disease": "What kind of diseases does the person have?",
 "Runaway date": "What was the date of the event?",
 "Total reward": "How much reward is offered?",
 "Given name": "What is the given name of the person?",
 "Origin": "Where does the person originate from?",
 "Owner": "Who is the owner of the person?",
 "Given surname": "What is the last name of the person?",
 "Injuries": "How was the person injured?",
 "Literacy": "What is the literacy level of the person?",
 "Name of contact": "Who is the contact person for the ad?",
 "Ran from region": "What is the name of the region from which the person escaped?",
 "Skills": "What is the set of skills of the person?",
 "Owner occupation": "What does the owner of the person do for a living?",
 "Motivation": "Why did the person escape his owner?",
 "Religion": "What is the religion of the person?",
 "Ran from specified": "What is the name of the place from which the person escaped?",
 "Contact occupation": "What does the contact of the ad do for a living?",
 "Physical characteristics": "What are the physical characteristics of the person?",
 "Stutters": "Does the person stutter?",
 "Plantation marks": "What plantation marks does the person have?",
 "Accused of crime": "What crimes did the person commit?",
 "Specified occupation": "What does the person do for a living?",
 "Racial descriptor": "What is the ethnicity of the person?",
 "Other reward": "What other rewards were offered?",
 "Owner address": "Where does the owner of the person live?",
 "Clothing": "What clothes did the person wear?",
 "Country marks": "What country marks does the person have?",
 "Destination (specified)": "What is the name of the destination?",
 "Also known as": "What other aliases does the person have?",
"Destination (region)": "What is the destination region of the person?",
"Language": "What are the communication skills of the person?",
 "Contact address": "Where does the contact person of the ad live?",
 "Physical scars": "What scars does the person have?",
 "Companions": "What are the names of the friends of the person?",
 "Personality": "What are the personality traits of the person?"
}

NUMERAL_ATTRIBUTES = {
    "Value pounds",
    "Value shillings",
    "Value pence",
    "Reward pounds",
    "Reward shillings",
    "Reward pence",
    "Age",
    "Height",
    "Total value",
}
BINARY_ATTRIBUTES = {"Warning notice", "Ran from ship", "Gender"}

# %%
IMAGE_FOLDER = "/projects/copenlu/data/nadav/pixel/runaways_scans/{}.png"
dataset_root_path = "/projects/copenlu/data/nadav/Datasets/runaways_visual/"

rng = np.random.RandomState(42)
wandb.init(config="/home/knf792/PycharmProjects/pixel-2/configs/squad_config.yaml", mode="disabled")
transform = SyntheticDatasetTransform(wandb.config, rng=rng)
squad_dataset = SquadDatasetForPixel(config=wandb.config, transform=transform, rng=rng)
# Out:
# Found cached dataset squad_v2 (/home/knf792/.cache/huggingface/datasets/squad_v2/squad_v2/2.0.0/09187c73c1b837c95d9a249cd97c2c3f1cebada06efe667b4427714b27639b1d)

# %%
def resize_image(args, image):
    """
    Resize the image to the specified size.
    """
    num_patches = 529
    if type(image) == np.ndarray:
        image = Image.fromarray(image)

    width, length = image.size
    if (
        width != args.image_width
    ):  # resize the image if the width is not the same as the specified width, without changing the aspect ratio
        ratio = width / args.image_width
        new_length = int(length / ratio)
        image = image.resize((args.image_width, new_length), Image.LANCZOS)

    if image.size[1] > args.image_height:  # crop the image if it's too long
        image = image.crop((0, 0, image.size[0], args.image_height))

    if args.embed_real_image:
        if image.size[1] < args.image_width:
            embedded_image = Image.new(
                "RGB",
                (args.image_width, args.image_height),
                (255, 255, 255),
            )
            embedded_image.paste(image, (0, 0))
            image = embedded_image

    else:  # we add black pixels to the image to make it square, and change the attention mask accordingly
        if image.size[1] == args.image_width:
            pass
        else:
            num_patches = (
                (args.image_width - image.size[1])
                // args.patch_base_size[0]
            ) * (args.image_height // args.patch_base_size[1])
            embedded_image = Image.new(
                "RGB",
                (args.image_width, args.image_height),
                (255, 255, 255),
            )
            embedded_image.paste(image, (0, 0))
            image = embedded_image
    return image, num_patches


def build_squad_example_from_instance(instance, squad_generator, args):
    image_id = instance["ID"][1:5]
    image = Image.open(f"/projects/copenlu/data/nadav/pixel/runaways_scans/{image_id}.png")
    resized_image, num_patches = resize_image(wandb.config, image)
    resized_image = np.array(resized_image)
    
    question = QUESTIONS[instance["attribute"]]
    question_image = squad_generator._generate_question(question)
    question_image = np.stack([question_image] * 3, axis=2)
    ad_image = np.concatenate([question_image, resized_image], axis=0)
    ad_image = ad_image[: args.image_height]
    
    answer = instance["answers"]["text"][0] if instance["answers"]["text"] else ""
    pixel_mask = squad_dataset.image_generator.generate_pixel_mask(ad_image, answer)
    return ad_image, pixel_mask

# %%
text_dataset = load_from_disk("/projects/copenlu/data/nadav/pixel/runaway_dataset")
all_ids = list(set(map(lambda x: x["ID"][1:5], text_dataset)))

random.shuffle(all_ids)
test_size = int(len(all_ids) * 0.2)
test_ids = all_ids[: test_size]
train_ids = all_ids[test_size:]

# %%
for instance in text_dataset:
    if os.path.exists(f"{dataset_root_path}/test/images/{instance['ID']}.png"):
        continue
    if instance["attribute"] not in QUESTIONS:
        continue
    if instance["ID"][1:5] in test_ids:
        print(instance["ID"])
        try:
            image, mask = build_squad_example_from_instance(instance, squad_dataset.image_generator, wandb.config)
        except FileNotFoundError:
            continue
        mask = convert_pixel_mask_to_patch_mask(
                mask,
                wandb.config.patch_base_size[0],
                wandb.config.mask_patching_tolerance,
            )
        mask = mask.astype("uint8")
        np.save(f"{dataset_root_path}/test/labels/{instance['ID']}.npy", mask)
        image = Image.fromarray(image)
        image.save(f"{dataset_root_path}/test/images/{instance['ID']}.png")

# %%
for instance in text_dataset:
    if os.path.exists(f"{dataset_root_path}/train/images/{instance['ID']}.png"):
        continue
    if instance["attribute"] not in QUESTIONS:
        continue
    if instance["ID"][1:5] in train_ids:
        print(instance["ID"])
        try:
            image, mask = build_squad_example_from_instance(instance, squad_dataset.image_generator, wandb.config)
        except FileNotFoundError:
            continue
        mask = convert_pixel_mask_to_patch_mask(
                mask,
                wandb.config.patch_base_size[0],
                wandb.config.mask_patching_tolerance,
            )
        mask = mask.astype("uint8")
        np.save(f"{dataset_root_path}/train/labels/{instance['ID']}.npy", mask)
        image = Image.fromarray(image)
        image.save(f"{dataset_root_path}/train/images/{instance['ID']}.png")
# Out:
# r0002Injuries
# r0002Stutters
# r0002Owner occupation
# r0002Contact address
# r0002Racial descriptor
# r0002Country marks
# r0002Destination (region)
# r0002Ran from specified
# r0002Origin
# r0002Plantation marks
# r0002Name of contact
# r0002Owner
# r0002Skills
# r0002Disease
# r0002Physical scars
# r0002Clothing
# r0002Accused of crime
# r0002Personality
# r0002Given surname
# r0002Also known as
# r0002Total reward
# r0002Ran from region
# r0002Owner address
# r0002Destination (specified)
# r0002Language
# r0002Other reward
# r0002Motivation
# r0002Literacy
# r0002Runaway date
# r0002Specified occupation
# r0002Given name
# r0002Religion
# r0002Physical characteristics
# r0002Companions
# r0002Contact occupation
# r0003Injuries
# r0003Stutters
# r0003Owner occupation
# r0003Contact address
# r0003Racial descriptor
# r0003Country marks
# r0003Destination (region)
# r0003Ran from specified
# r0003Origin
# r0003Plantation marks
# r0003Name of contact
# r0003Owner
# r0003Skills
# r0003Disease
# r0003Physical scars
# r0003Clothing
# r0003Accused of crime
# r0003Personality
# r0003Given surname
# r0003Also known as
# r0003Total reward
# r0003Ran from region
# r0003Owner address
# r0003Destination (specified)
# r0003Language
# r0003Other reward
# r0003Motivation
# r0003Literacy
# r0003Runaway date
# r0003Specified occupation
# r0003Given name
# r0003Religion
# r0003Physical characteristics
# r0003Companions
# r0003Contact occupation
# r0004Injuries
# r0004Stutters
# r0004Owner occupation
# r0004Contact address
# r0004Racial descriptor
# r0004Country marks
# r0004Destination (region)
# r0004Ran from specified
# r0004Origin
# r0004Plantation marks
# r0004Name of contact
# r0004Owner
# r0004Skills
# r0004Disease
# r0004Physical scars
# r0004Clothing
# r0004Accused of crime
# r0004Personality
# r0004Given surname
# r0004Also known as
# r0004Total reward
# r0004Ran from region
# r0004Owner address
# r0004Destination (specified)
# r0004Language
# r0004Other reward
# r0004Motivation
# r0004Literacy
# r0004Runaway date
# r0004Specified occupation
# r0004Given name
# r0004Religion
# r0004Physical characteristics
# r0004Companions
# r0004Contact occupation
# r0005Injuries
# r0005Stutters
# r0005Owner occupation
# r0005Contact address
# r0005Racial descriptor
# r0005Country marks
# r0005Destination (region)
# r0005Ran from specified
# r0005Origin
# r0005Plantation marks
# r0005Name of contact
# r0005Owner
# r0005Skills
# r0005Disease
# r0005Physical scars
# r0005Clothing
# r0005Accused of crime
# r0005Personality
# r0005Given surname
# r0005Also known as
# r0005Total reward
# r0005Ran from region
# r0005Owner address
# r0005Destination (specified)
# r0005Language
# r0005Other reward
# r0005Motivation
# r0005Literacy
# r0005Runaway date
# r0005Specified occupation
# r0005Given name
# r0005Religion
# r0005Physical characteristics
# r0005Companions
# r0005Contact occupation
# r0006Injuries
# r0006Stutters
# r0006Owner occupation
# r0006Contact address
# r0006Racial descriptor
# r0006Country marks
# r0006Destination (region)
# r0006Ran from specified
# r0006Origin
# r0006Plantation marks
# r0006Name of contact
# r0006Owner
# r0006Skills
# r0006Disease
# r0006Physical scars
# r0006Clothing
# r0006Accused of crime
# r0006Personality
# r0006Given surname
# r0006Also known as
# r0006Total reward
# r0006Ran from region
# r0006Owner address
# r0006Destination (specified)
# r0006Language
# r0006Other reward
# r0006Motivation
# r0006Literacy
# r0006Runaway date
# r0006Specified occupation
# r0006Given name
# r0006Religion
# r0006Physical characteristics
# r0006Companions
# r0006Contact occupation
# r0007Injuries
# r0007Stutters
# r0007Owner occupation
# r0007Contact address
# r0007Racial descriptor
# r0007Country marks
# r0007Destination (region)
# r0007Ran from specified
# r0007Origin
# r0007Plantation marks
# r0007Name of contact
# r0007Owner
# r0007Skills
# r0007Disease
# r0007Physical scars
# r0007Clothing
# r0007Accused of crime
# r0007Personality
# r0007Given surname
# r0007Also known as
# r0007Total reward
# r0007Ran from region
# r0007Owner address
# r0007Destination (specified)
# r0007Language
# r0007Other reward
# r0007Motivation
# r0007Literacy
# r0007Runaway date
# r0007Specified occupation
# r0007Given name
# r0007Religion
# r0007Physical characteristics
# r0007Companions
# r0007Contact occupation
# r0008Injuries
# r0008Stutters
# r0008Owner occupation
# r0008Contact address
# r0008Racial descriptor
# r0008Country marks
# r0008Destination (region)
# r0008Ran from specified
# r0008Origin
# r0008Plantation marks
# r0008Name of contact
# r0008Owner
# r0008Skills
# r0008Disease
# r0008Physical scars
# r0008Clothing
# r0008Accused of crime
# r0008Personality
# r0008Given surname
# r0008Also known as
# r0008Total reward
# r0008Ran from region
# r0008Owner address
# r0008Destination (specified)
# r0008Language
# r0008Other reward
# r0008Motivation
# r0008Literacy
# r0008Runaway date
# r0008Specified occupation
# r0008Given name
# r0008Religion
# r0008Physical characteristics
# r0008Companions
# r0008Contact occupation
# r0010Injuries
# r0010Stutters
# r0010Owner occupation
# r0010Contact address
# r0010Racial descriptor
# r0010Country marks
# r0010Destination (region)
# r0010Ran from specified
# r0010Origin
# r0010Plantation marks
# r0010Name of contact
# r0010Owner
# r0010Skills
# r0010Disease
# r0010Physical scars
# r0010Clothing
# r0010Accused of crime
# r0010Personality
# r0010Given surname
# r0010Also known as
# r0010Total reward
# r0010Ran from region
# r0010Owner address
# r0010Destination (specified)
# r0010Language
# r0010Other reward
# r0010Motivation
# r0010Literacy
# r0010Runaway date
# r0010Specified occupation
# r0010Given name
# r0010Religion
# r0010Physical characteristics
# r0010Companions
# r0010Contact occupation
# r0012Injuries
# r0012Stutters
# r0012Owner occupation
# r0012Contact address
# r0012Racial descriptor
# r0012Country marks
# r0012Destination (region)
# r0012Ran from specified
# r0012Origin
# r0012Plantation marks
# r0012Name of contact
# r0012Owner
# r0012Skills
# r0012Disease
# r0012Physical scars
# r0012Clothing
# r0012Accused of crime
# r0012Personality
# r0012Given surname
# r0012Also known as
# r0012Total reward
# r0012Ran from region
# r0012Owner address
# r0012Destination (specified)
# r0012Language
# r0012Other reward
# r0012Motivation
# r0012Literacy
# r0012Runaway date
# r0012Specified occupation
# r0012Given name
# r0012Religion
# r0012Physical characteristics
# r0012Companions
# r0012Contact occupation
# r0014Injuries
# r0014Stutters
# r0014Owner occupation
# r0014Contact address
# r0014Racial descriptor
# r0014Country marks
# r0014Destination (region)
# r0014Ran from specified
# r0014Origin
# r0014Plantation marks
# r0014Name of contact
# r0014Owner
# r0014Skills
# r0014Disease
# r0014Physical scars
# r0014Clothing
# r0014Accused of crime
# r0014Personality
# r0014Given surname
# r0014Also known as
# r0014Total reward
# r0014Ran from region
# r0014Owner address
# r0014Destination (specified)
# r0014Language
# r0014Other reward
# r0014Motivation
# r0014Literacy
# r0014Runaway date
# r0014Specified occupation
# r0014Given name
# r0014Religion
# r0014Physical characteristics
# r0014Companions
# r0014Contact occupation
# r0015Injuries
# r0015Stutters
# r0015Owner occupation
# r0015Contact address
# r0015Racial descriptor
# r0015Country marks
# r0015Destination (region)
# r0015Ran from specified
# r0015Origin
# r0015Plantation marks
# r0015Name of contact
# r0015Owner
# r0015Skills
# r0015Disease
# r0015Physical scars
# r0015Clothing
# r0015Accused of crime
# r0015Personality
# r0015Given surname
# r0015Also known as
# r0015Total reward
# r0015Ran from region
# r0015Owner address
# r0015Destination (specified)
# r0015Language
# r0015Other reward
# r0015Motivation
# r0015Literacy
# r0015Runaway date
# r0015Specified occupation
# r0015Given name
# r0015Religion
# r0015Physical characteristics
# r0015Companions
# r0015Contact occupation
# r0017Injuries
# r0017Stutters
# r0017Owner occupation
# r0017Contact address
# r0017Racial descriptor
# r0017Country marks
# r0017Destination (region)
# r0017Ran from specified
# r0017Origin
# r0017Plantation marks
# r0017Name of contact
# r0017Owner
# r0017Skills
# r0017Disease
# r0017Physical scars
# r0017Clothing
# r0017Accused of crime
# r0017Personality
# r0017Given surname
# r0017Also known as
# r0017Total reward
# r0017Ran from region
# r0017Owner address
# r0017Destination (specified)
# r0017Language
# r0017Other reward
# r0017Motivation
# r0017Literacy
# r0017Runaway date
# r0017Specified occupation
# r0017Given name
# r0017Religion
# r0017Physical characteristics
# r0017Companions
# r0017Contact occupation
# r0018Injuries
# r0018Stutters
# r0018Owner occupation
# r0018Contact address
# r0018Racial descriptor
# r0018Country marks
# r0018Destination (region)
# r0018Ran from specified
# r0018Origin
# r0018Plantation marks
# r0018Name of contact
# r0018Owner
# r0018Skills
# r0018Disease
# r0018Physical scars
# r0018Clothing
# r0018Accused of crime
# r0018Personality
# r0018Given surname
# r0018Also known as
# r0018Total reward
# r0018Ran from region
# r0018Owner address
# r0018Destination (specified)
# r0018Language
# r0018Other reward
# r0018Motivation
# r0018Literacy
# r0018Runaway date
# r0018Specified occupation
# r0018Given name
# r0018Religion
# r0018Physical characteristics
# r0018Companions
# r0018Contact occupation
# r0019Injuries
# r0019Stutters
# r0019Owner occupation
# r0019Contact address
# r0019Racial descriptor
# r0019Country marks
# r0019Destination (region)
# r0019Ran from specified
# r0019Origin
# r0019Plantation marks
# r0019Name of contact
# r0019Owner
# r0019Skills
# r0019Disease
# r0019Physical scars
# r0019Clothing
# r0019Accused of crime
# r0019Personality
# r0019Given surname
# r0019Also known as
# r0019Total reward
# r0019Ran from region
# r0019Owner address
# r0019Destination (specified)
# r0019Language
# r0019Other reward
# r0019Motivation
# r0019Literacy
# r0019Runaway date
# r0019Specified occupation
# r0019Given name
# r0019Religion
# r0019Physical characteristics
# r0019Companions
# r0019Contact occupation
# r0020Injuries
# r0020Stutters
# r0020Owner occupation
# r0020Contact address
# r0020Racial descriptor
# r0020Country marks
# r0020Destination (region)
# r0020Ran from specified
# r0020Origin
# r0020Plantation marks
# r0020Name of contact
# r0020Owner
# r0020Skills
# r0020Disease
# r0020Physical scars
# r0020Clothing
# r0020Accused of crime
# r0020Personality
# r0020Given surname
# r0020Also known as
# r0020Total reward
# r0020Ran from region
# r0020Owner address
# r0020Destination (specified)
# r0020Language
# r0020Other reward
# r0020Motivation
# r0020Literacy
# r0020Runaway date
# r0020Specified occupation
# r0020Given name
# r0020Religion
# r0020Physical characteristics
# r0020Companions
# r0020Contact occupation
# r0021Injuries
# r0021Stutters
# r0021Owner occupation
# r0021Contact address
# r0021Racial descriptor
# r0021Country marks
# r0021Destination (region)
# r0021Ran from specified
# r0021Origin
# r0021Plantation marks
# r0021Name of contact
# r0021Owner
# r0021Skills
# r0021Disease
# r0021Physical scars
# r0021Clothing
# r0021Accused of crime
# r0021Personality
# r0021Given surname
# r0021Also known as
# r0021Total reward
# r0021Ran from region
# r0021Owner address
# r0021Destination (specified)
# r0021Language
# r0021Other reward
# r0021Motivation
# r0021Literacy
# r0021Runaway date
# r0021Specified occupation
# r0021Given name
# r0021Religion
# r0021Physical characteristics
# r0021Companions
# r0021Contact occupation
# r0023Injuries
# r0023Stutters
# r0023Owner occupation
# r0023Contact address
# r0023Racial descriptor
# r0023Country marks
# r0023Destination (region)
# r0023Ran from specified
# r0023Origin
# r0023Plantation marks
# r0023Name of contact
# r0023Owner
# r0023Skills
# r0023Disease
# r0023Physical scars
# r0023Clothing
# r0023Accused of crime
# r0023Personality
# r0023Given surname
# r0023Also known as
# r0023Total reward
# r0023Ran from region
# r0023Owner address
# r0023Destination (specified)
# r0023Language
# r0023Other reward
# r0023Motivation
# r0023Literacy
# r0023Runaway date
# r0023Specified occupation
# r0023Given name
# r0023Religion
# r0023Physical characteristics
# r0023Companions
# r0023Contact occupation
# r0024Injuries
# r0024Stutters
# r0024Owner occupation
# r0024Contact address
# r0024Racial descriptor
# r0024Country marks
# r0024Destination (region)
# r0024Ran from specified
# r0024Origin
# r0024Plantation marks
# r0024Name of contact
# r0024Owner
# r0024Skills
# r0024Disease
# r0024Physical scars
# r0024Clothing
# r0024Accused of crime
# r0024Personality
# r0024Given surname
# r0024Also known as
# r0024Total reward
# r0024Ran from region
# r0024Owner address
# r0024Destination (specified)
# r0024Language
# r0024Other reward
# r0024Motivation
# r0024Literacy
# r0024Runaway date
# r0024Specified occupation
# r0024Given name
# r0024Religion
# r0024Physical characteristics
# r0024Companions
# r0024Contact occupation
# r0025Injuries
# r0025Stutters
# r0025Owner occupation
# r0025Contact address
# r0025Racial descriptor
# r0025Country marks
# r0025Destination (region)
# r0025Ran from specified
# r0025Origin
# r0025Plantation marks
# r0025Name of contact
# r0025Owner
# r0025Skills
# r0025Disease
# r0025Physical scars
# r0025Clothing
# r0025Accused of crime
# r0025Personality
# r0025Given surname
# r0025Also known as
# r0025Total reward
# r0025Ran from region
# r0025Owner address
# r0025Destination (specified)
# r0025Language
# r0025Other reward
# r0025Motivation
# r0025Literacy
# r0025Runaway date
# r0025Specified occupation
# r0025Given name
# r0025Religion
# r0025Physical characteristics
# r0025Companions
# r0025Contact occupation
# r0026Injuries
# r0026Stutters
# r0026Owner occupation
# r0026Contact address
# r0026Racial descriptor
# r0026Country marks
# r0026Destination (region)
# r0026Ran from specified
# r0026Origin
# r0026Plantation marks
# r0026Name of contact
# r0026Owner
# r0026Skills
# r0026Disease
# r0026Physical scars
# r0026Clothing
# r0026Accused of crime
# r0026Personality
# r0026Given surname
# r0026Also known as
# r0026Total reward
# r0026Ran from region
# r0026Owner address
# r0026Destination (specified)
# r0026Language
# r0026Other reward
# r0026Motivation
# r0026Literacy
# r0026Runaway date
# r0026Specified occupation
# r0026Given name
# r0026Religion
# r0026Physical characteristics
# r0026Companions
# r0026Contact occupation
# r0027Injuries
# r0027Stutters
# r0027Owner occupation
# r0027Contact address
# r0027Racial descriptor
# r0027Country marks
# r0027Destination (region)
# r0027Ran from specified
# r0027Origin
# r0027Plantation marks
# r0027Name of contact
# r0027Owner
# r0027Skills
# r0027Disease
# r0027Physical scars
# r0027Clothing
# r0027Accused of crime
# r0027Personality
# r0027Given surname
# r0027Also known as
# r0027Total reward
# r0027Ran from region
# r0027Owner address
# r0027Destination (specified)
# r0027Language
# r0027Other reward
# r0027Motivation
# r0027Literacy
# r0027Runaway date
# r0027Specified occupation
# r0027Given name
# r0027Religion
# r0027Physical characteristics
# r0027Companions
# r0027Contact occupation
# r0028Injuries
# r0028Stutters
# r0028Owner occupation
# r0028Contact address
# r0028Racial descriptor
# r0028Country marks
# r0028Destination (region)
# r0028Ran from specified
# r0028Origin
# r0028Plantation marks
# r0028Name of contact
# r0028Owner
# r0028Skills
# r0028Disease
# r0028Physical scars
# r0028Clothing
# r0028Accused of crime
# r0028Personality
# r0028Given surname
# r0028Also known as
# r0028Total reward
# r0028Ran from region
# r0028Owner address
# r0028Destination (specified)
# r0028Language
# r0028Other reward
# r0028Motivation
# r0028Literacy
# r0028Runaway date
# r0028Specified occupation
# r0028Given name
# r0028Religion
# r0028Physical characteristics
# r0028Companions
# r0028Contact occupation
# r0029Injuries
# r0029Stutters
# r0029Owner occupation
# r0029Contact address
# r0029Racial descriptor
# r0029Country marks
# r0029Destination (region)
# r0029Ran from specified
# r0029Origin
# r0029Plantation marks
# r0029Name of contact
# r0029Owner
# r0029Skills
# r0029Disease
# r0029Physical scars
# r0029Clothing
# r0029Accused of crime
# r0029Personality
# r0029Given surname
# r0029Also known as
# r0029Total reward
# r0029Ran from region
# r0029Owner address
# r0029Destination (specified)
# r0029Language
# r0029Other reward
# r0029Motivation
# r0029Literacy
# r0029Runaway date
# r0029Specified occupation
# r0029Given name
# r0029Religion
# r0029Physical characteristics
# r0029Companions
# r0029Contact occupation
# r0030Injuries
# r0030Stutters
# r0030Owner occupation
# r0030Contact address
# r0030Racial descriptor
# r0030Country marks
# r0030Destination (region)
# r0030Ran from specified
# r0030Origin
# r0030Plantation marks
# r0030Name of contact
# r0030Owner
# r0030Skills
# r0030Disease
# r0030Physical scars
# r0030Clothing
# r0030Accused of crime
# r0030Personality
# r0030Given surname
# r0030Also known as
# r0030Total reward
# r0030Ran from region
# r0030Owner address
# r0030Destination (specified)
# r0030Language
# r0030Other reward
# r0030Motivation
# r0030Literacy
# r0030Runaway date
# r0030Specified occupation
# r0030Given name
# r0030Religion
# r0030Physical characteristics
# r0030Companions
# r0030Contact occupation
# r0031Injuries
# r0031Stutters
# r0031Owner occupation
# r0031Contact address
# r0031Racial descriptor
# r0031Country marks
# r0031Destination (region)
# r0031Ran from specified
# r0031Origin
# r0031Plantation marks
# r0031Name of contact
# r0031Owner
# r0031Skills
# r0031Disease
# r0031Physical scars
# r0031Clothing
# r0031Accused of crime
# r0031Personality
# r0031Given surname
# r0031Also known as
# r0031Total reward
# r0031Ran from region
# r0031Owner address
# r0031Destination (specified)
# r0031Language
# r0031Other reward
# r0031Motivation
# r0031Literacy
# r0031Runaway date
# r0031Specified occupation
# r0031Given name
# r0031Religion
# r0031Physical characteristics
# r0031Companions
# r0031Contact occupation
# r0032Injuries
# r0032Stutters
# r0032Owner occupation
# r0032Contact address
# r0032Racial descriptor
# r0032Country marks
# r0032Destination (region)
# r0032Ran from specified
# r0032Origin
# r0032Plantation marks
# r0032Name of contact
# r0032Owner
# r0032Skills
# r0032Disease
# r0032Physical scars
# r0032Clothing
# r0032Accused of crime
# r0032Personality
# r0032Given surname
# r0032Also known as
# r0032Total reward
# r0032Ran from region
# r0032Owner address
# r0032Destination (specified)
# r0032Language
# r0032Other reward
# r0032Motivation
# r0032Literacy
# r0032Runaway date
# r0032Specified occupation
# r0032Given name
# r0032Religion
# r0032Physical characteristics
# r0032Companions
# r0032Contact occupation
# r0034Injuries
# r0034Stutters
# r0034Owner occupation
# r0034Contact address
# r0034Racial descriptor
# r0034Country marks
# r0034Destination (region)
# r0034Ran from specified
# r0034Origin
# r0034Plantation marks
# r0034Name of contact
# r0034Owner
# r0034Skills
# r0034Disease
# r0034Physical scars
# r0034Clothing
# r0034Accused of crime
# r0034Personality
# r0034Given surname
# r0034Also known as
# r0034Total reward
# r0034Ran from region
# r0034Owner address
# r0034Destination (specified)
# r0034Language
# r0034Other reward
# r0034Motivation
# r0034Literacy
# r0034Runaway date
# r0034Specified occupation
# r0034Given name
# r0034Religion
# r0034Physical characteristics
# r0034Companions
# r0034Contact occupation
# r0035Injuries
# r0035Stutters
# r0035Owner occupation
# r0035Contact address
# r0035Racial descriptor
# r0035Country marks
# r0035Destination (region)
# r0035Ran from specified
# r0035Origin
# r0035Plantation marks
# r0035Name of contact
# r0035Owner
# r0035Skills
# r0035Disease
# r0035Physical scars
# r0035Clothing
# r0035Accused of crime
# r0035Personality
# r0035Given surname
# r0035Also known as
# r0035Total reward
# r0035Ran from region
# r0035Owner address
# r0035Destination (specified)
# r0035Language
# r0035Other reward
# r0035Motivation
# r0035Literacy
# r0035Runaway date
# r0035Specified occupation
# r0035Given name
# r0035Religion
# r0035Physical characteristics
# r0035Companions
# r0035Contact occupation
# r0036Injuries
# r0036Stutters
# r0036Owner occupation
# r0036Contact address
# r0036Racial descriptor
# r0036Country marks
# r0036Destination (region)
# r0036Ran from specified
# r0036Origin
# r0036Plantation marks
# r0036Name of contact
# r0036Owner
# r0036Skills
# r0036Disease
# r0036Physical scars
# r0036Clothing
# r0036Accused of crime
# r0036Personality
# r0036Given surname
# r0036Also known as
# r0036Total reward
# r0036Ran from region
# r0036Owner address
# r0036Destination (specified)
# r0036Language
# r0036Other reward
# r0036Motivation
# r0036Literacy
# r0036Runaway date
# r0036Specified occupation
# r0036Given name
# r0036Religion
# r0036Physical characteristics
# r0036Companions
# r0036Contact occupation
# r0037Injuries
# r0037Stutters
# r0037Owner occupation
# r0037Contact address
# r0037Racial descriptor
# r0037Country marks
# r0037Destination (region)
# r0037Ran from specified
# r0037Origin
# r0037Plantation marks
# r0037Name of contact
# r0037Owner
# r0037Skills
# r0037Disease
# r0037Physical scars
# r0037Clothing
# r0037Accused of crime
# r0037Personality
# r0037Given surname
# r0037Also known as
# r0037Total reward
# r0037Ran from region
# r0037Owner address
# r0037Destination (specified)
# r0037Language
# r0037Other reward
# r0037Motivation
# r0037Literacy
# r0037Runaway date
# r0037Specified occupation
# r0037Given name
# r0037Religion
# r0037Physical characteristics
# r0037Companions
# r0037Contact occupation
# r0038Injuries
# r0038Stutters
# r0038Owner occupation
# r0038Contact address
# r0038Racial descriptor
# r0038Country marks
# r0038Destination (region)
# r0038Ran from specified
# r0038Origin
# r0038Plantation marks
# r0038Name of contact
# r0038Owner
# r0038Skills
# r0038Disease
# r0038Physical scars
# r0038Clothing
# r0038Accused of crime
# r0038Personality
# r0038Given surname
# r0038Also known as
# r0038Total reward
# r0038Ran from region
# r0038Owner address
# r0038Destination (specified)
# r0038Language
# r0038Other reward
# r0038Motivation
# r0038Literacy
# r0038Runaway date
# r0038Specified occupation
# r0038Given name
# r0038Religion
# r0038Physical characteristics
# r0038Companions
# r0038Contact occupation
# r0039Injuries
# r0039Stutters
# r0039Owner occupation
# r0039Contact address
# r0039Racial descriptor
# r0039Country marks
# r0039Destination (region)
# r0039Ran from specified
# r0039Origin
# r0039Plantation marks
# r0039Name of contact
# r0039Owner
# r0039Skills
# r0039Disease
# r0039Physical scars
# r0039Clothing
# r0039Accused of crime
# r0039Personality
# r0039Given surname
# r0039Also known as
# r0039Total reward
# r0039Ran from region
# r0039Owner address
# r0039Destination (specified)
# r0039Language
# r0039Other reward
# r0039Motivation
# r0039Literacy
# r0039Runaway date
# r0039Specified occupation
# r0039Given name
# r0039Religion
# r0039Physical characteristics
# r0039Companions
# r0039Contact occupation
# r0040Injuries
# r0040Stutters
# r0040Owner occupation
# r0040Contact address
# r0040Racial descriptor
# r0040Country marks
# r0040Destination (region)
# r0040Ran from specified
# r0040Origin
# r0040Plantation marks
# r0040Name of contact
# r0040Owner
# r0040Skills
# r0040Disease
# r0040Physical scars
# r0040Clothing
# r0040Accused of crime
# r0040Personality
# r0040Given surname
# r0040Also known as
# r0040Total reward
# r0040Ran from region
# r0040Owner address
# r0040Destination (specified)
# r0040Language
# r0040Other reward
# r0040Motivation
# r0040Literacy
# r0040Runaway date
# r0040Specified occupation
# r0040Given name
# r0040Religion
# r0040Physical characteristics
# r0040Companions
# r0040Contact occupation
# r0041Injuries
# r0041Stutters
# r0041Owner occupation
# r0041Contact address
# r0041Racial descriptor
# r0041Country marks
# r0041Destination (region)
# r0041Ran from specified
# r0041Origin
# r0041Plantation marks
# r0041Name of contact
# r0041Owner
# r0041Skills
# r0041Disease
# r0041Physical scars
# r0041Clothing
# r0041Accused of crime
# r0041Personality
# r0041Given surname
# r0041Also known as
# r0041Total reward
# r0041Ran from region
# r0041Owner address
# r0041Destination (specified)
# r0041Language
# r0041Other reward
# r0041Motivation
# r0041Literacy
# r0041Runaway date
# r0041Specified occupation
# r0041Given name
# r0041Religion
# r0041Physical characteristics
# r0041Companions
# r0041Contact occupation
# r0042Injuries
# r0042Stutters
# r0042Owner occupation
# r0042Contact address
# r0042Racial descriptor
# r0042Country marks
# r0042Destination (region)
# r0042Ran from specified
# r0042Origin
# r0042Plantation marks
# r0042Name of contact
# r0042Owner
# r0042Skills
# r0042Disease
# r0042Physical scars
# r0042Clothing
# r0042Accused of crime
# r0042Personality
# r0042Given surname
# r0042Also known as
# r0042Total reward
# r0042Ran from region
# r0042Owner address
# r0042Destination (specified)
# r0042Language
# r0042Other reward
# r0042Motivation
# r0042Literacy
# r0042Runaway date
# r0042Specified occupation
# r0042Given name
# r0042Religion
# r0042Physical characteristics
# r0042Companions
# r0042Contact occupation
# r0043Injuries
# r0043Stutters
# r0043Owner occupation
# r0043Contact address
# r0043Racial descriptor
# r0043Country marks
# r0043Destination (region)
# r0043Ran from specified
# r0043Origin
# r0043Plantation marks
# r0043Name of contact
# r0043Owner
# r0043Skills
# r0043Disease
# r0043Physical scars
# r0043Clothing
# r0043Accused of crime
# r0043Personality
# r0043Given surname
# r0043Also known as
# r0043Total reward
# r0043Ran from region
# r0043Owner address
# r0043Destination (specified)
# r0043Language
# r0043Other reward
# r0043Motivation
# r0043Literacy
# r0043Runaway date
# r0043Specified occupation
# r0043Given name
# r0043Religion
# r0043Physical characteristics
# r0043Companions
# r0043Contact occupation
# r0044Injuries
# r0044Stutters
# r0044Owner occupation
# r0044Contact address
# r0044Racial descriptor
# r0044Country marks
# r0044Destination (region)
# r0044Ran from specified
# r0044Origin
# r0044Plantation marks
# r0044Name of contact
# r0044Owner
# r0044Skills
# r0044Disease
# r0044Physical scars
# r0044Clothing
# r0044Accused of crime
# r0044Personality
# r0044Given surname
# r0044Also known as
# r0044Total reward
# r0044Ran from region
# r0044Owner address
# r0044Destination (specified)
# r0044Language
# r0044Other reward
# r0044Motivation
# r0044Literacy
# r0044Runaway date
# r0044Specified occupation
# r0044Given name
# r0044Religion
# r0044Physical characteristics
# r0044Companions
# r0044Contact occupation
# r0045Injuries
# r0045Stutters
# r0045Owner occupation
# r0045Contact address
# r0045Racial descriptor
# r0045Country marks
# r0045Destination (region)
# r0045Ran from specified
# r0045Origin
# r0045Plantation marks
# r0045Name of contact
# r0045Owner
# r0045Skills
# r0045Disease
# r0045Physical scars
# r0045Clothing
# r0045Accused of crime
# r0045Personality
# r0045Given surname
# r0045Also known as
# r0045Total reward
# r0045Ran from region
# r0045Owner address
# r0045Destination (specified)
# r0045Language
# r0045Other reward
# r0045Motivation
# r0045Literacy
# r0045Runaway date
# r0045Specified occupation
# r0045Given name
# r0045Religion
# r0045Physical characteristics
# r0045Companions
# r0045Contact occupation
# r0046Injuries
# r0046Stutters
# r0046Owner occupation
# r0046Contact address
# r0046Racial descriptor
# r0046Country marks
# r0046Destination (region)
# r0046Ran from specified
# r0046Origin
# r0046Plantation marks
# r0046Name of contact
# r0046Owner
# r0046Skills
# r0046Disease
# r0046Physical scars
# r0046Clothing
# r0046Accused of crime
# r0046Personality
# r0046Given surname
# r0046Also known as
# r0046Total reward
# r0046Ran from region
# r0046Owner address
# r0046Destination (specified)
# r0046Language
# r0046Other reward
# r0046Motivation
# r0046Literacy
# r0046Runaway date
# r0046Specified occupation
# r0046Given name
# r0046Religion
# r0046Physical characteristics
# r0046Companions
# r0046Contact occupation
# r0047Injuries
# r0047Stutters
# r0047Owner occupation
# r0047Contact address
# r0047Racial descriptor
# r0047Country marks
# r0047Destination (region)
# r0047Ran from specified
# r0047Origin
# r0047Plantation marks
# r0047Name of contact
# r0047Owner
# r0047Skills
# r0047Disease
# r0047Physical scars
# r0047Clothing
# r0047Accused of crime
# r0047Personality
# r0047Given surname
# r0047Also known as
# r0047Total reward
# r0047Ran from region
# r0047Owner address
# r0047Destination (specified)
# r0047Language
# r0047Other reward
# r0047Motivation
# r0047Literacy
# r0047Runaway date
# r0047Specified occupation
# r0047Given name
# r0047Religion
# r0047Physical characteristics
# r0047Companions
# r0047Contact occupation
# r0048Injuries
# r0048Stutters
# r0048Owner occupation
# r0048Contact address
# r0048Racial descriptor
# r0048Country marks
# r0048Destination (region)
# r0048Ran from specified
# r0048Origin
# r0048Plantation marks
# r0048Name of contact
# r0048Owner
# r0048Skills
# r0048Disease
# r0048Physical scars
# r0048Clothing
# r0048Accused of crime
# r0048Personality
# r0048Given surname
# r0048Also known as
# r0048Total reward
# r0048Ran from region
# r0048Owner address
# r0048Destination (specified)
# r0048Language
# r0048Other reward
# r0048Motivation
# r0048Literacy
# r0048Runaway date
# r0048Specified occupation
# r0048Given name
# r0048Religion
# r0048Physical characteristics
# r0048Companions
# r0048Contact occupation
# r0049Injuries
# r0049Stutters
# r0049Owner occupation
# r0049Contact address
# r0049Racial descriptor
# r0049Country marks
# r0049Destination (region)
# r0049Ran from specified
# r0049Origin
# r0049Plantation marks
# r0049Name of contact
# r0049Owner
# r0049Skills
# r0049Disease
# r0049Physical scars
# r0049Clothing
# r0049Accused of crime
# r0049Personality
# r0049Given surname
# r0049Also known as
# r0049Total reward
# r0049Ran from region
# r0049Owner address
# r0049Destination (specified)
# r0049Language
# r0049Other reward
# r0049Motivation
# r0049Literacy
# r0049Runaway date
# r0049Specified occupation
# r0049Given name
# r0049Religion
# r0049Physical characteristics
# r0049Companions
# r0049Contact occupation
# r0050Injuries
# r0050Stutters
# r0050Owner occupation
# r0050Contact address
# r0050Racial descriptor
# r0050Country marks
# r0050Destination (region)
# r0050Ran from specified
# r0050Origin
# r0050Plantation marks
# r0050Name of contact
# r0050Owner
# r0050Skills
# r0050Disease
# r0050Physical scars
# r0050Clothing
# r0050Accused of crime
# r0050Personality
# r0050Given surname
# r0050Also known as
# r0050Total reward
# r0050Ran from region
# r0050Owner address
# r0050Destination (specified)
# r0050Language
# r0050Other reward
# r0050Motivation
# r0050Literacy
# r0050Runaway date
# r0050Specified occupation
# r0050Given name
# r0050Religion
# r0050Physical characteristics
# r0050Companions
# r0050Contact occupation
# r0052Injuries
# r0052Stutters
# r0052Owner occupation
# r0052Contact address
# r0052Racial descriptor
# r0052Country marks
# r0052Destination (region)
# r0052Ran from specified
# r0052Origin
# r0052Plantation marks
# r0052Name of contact
# r0052Owner
# r0052Skills
# r0052Disease
# r0052Physical scars
# r0052Clothing
# r0052Accused of crime
# r0052Personality
# r0052Given surname
# r0052Also known as
# r0052Total reward
# r0052Ran from region
# r0052Owner address
# r0052Destination (specified)
# r0052Language
# r0052Other reward
# r0052Motivation
# r0052Literacy
# r0052Runaway date
# r0052Specified occupation
# r0052Given name
# r0052Religion
# r0052Physical characteristics
# r0052Companions
# r0052Contact occupation
# r0053Injuries
# r0053Stutters
# r0053Owner occupation
# r0053Contact address
# r0053Racial descriptor
# r0053Country marks
# r0053Destination (region)
# r0053Ran from specified
# r0053Origin
# r0053Plantation marks
# r0053Name of contact
# r0053Owner
# r0053Skills
# r0053Disease
# r0053Physical scars
# r0053Clothing
# r0053Accused of crime
# r0053Personality
# r0053Given surname
# r0053Also known as
# r0053Total reward
# r0053Ran from region
# r0053Owner address
# r0053Destination (specified)
# r0053Language
# r0053Other reward
# r0053Motivation
# r0053Literacy
# r0053Runaway date
# r0053Specified occupation
# r0053Given name
# r0053Religion
# r0053Physical characteristics
# r0053Companions
# r0053Contact occupation
# r0055Injuries
# r0055Stutters
# r0055Owner occupation
# r0055Contact address
# r0055Racial descriptor
# r0055Country marks
# r0055Destination (region)
# r0055Ran from specified
# r0055Origin
# r0055Plantation marks
# r0055Name of contact
# r0055Owner
# r0055Skills
# r0055Disease
# r0055Physical scars
# r0055Clothing
# r0055Accused of crime
# r0055Personality
# r0055Given surname
# r0055Also known as
# r0055Total reward
# r0055Ran from region
# r0055Owner address
# r0055Destination (specified)
# r0055Language
# r0055Other reward
# r0055Motivation
# r0055Literacy
# r0055Runaway date
# r0055Specified occupation
# r0055Given name
# r0055Religion
# r0055Physical characteristics
# r0055Companions
# r0055Contact occupation
# r0056Injuries
# r0056Stutters
# r0056Owner occupation
# r0056Contact address
# r0056Racial descriptor
# r0056Country marks
# r0056Destination (region)
# r0056Ran from specified
# r0056Origin
# r0056Plantation marks
# r0056Name of contact
# r0056Owner
# r0056Skills
# r0056Disease
# r0056Physical scars
# r0056Clothing
# r0056Accused of crime
# r0056Personality
# r0056Given surname
# r0056Also known as
# r0056Total reward
# r0056Ran from region
# r0056Owner address
# r0056Destination (specified)
# r0056Language
# r0056Other reward
# r0056Motivation
# r0056Literacy
# r0056Runaway date
# r0056Specified occupation
# r0056Given name
# r0056Religion
# r0056Physical characteristics
# r0056Companions
# r0056Contact occupation
# r0057Injuries
# r0057Stutters
# r0057Owner occupation
# r0057Contact address
# r0057Racial descriptor
# r0057Country marks
# r0057Destination (region)
# r0057Ran from specified
# r0057Origin
# r0057Plantation marks
# r0057Name of contact
# r0057Owner
# r0057Skills
# r0057Disease
# r0057Physical scars
# r0057Clothing
# r0057Accused of crime
# r0057Personality
# r0057Given surname
# r0057Also known as
# r0057Total reward
# r0057Ran from region
# r0057Owner address
# r0057Destination (specified)
# r0057Language
# r0057Other reward
# r0057Motivation
# r0057Literacy
# r0057Runaway date
# r0057Specified occupation
# r0057Given name
# r0057Religion
# r0057Physical characteristics
# r0057Companions
# r0057Contact occupation
# r0058Injuries
# r0058Stutters
# r0058Owner occupation
# r0058Contact address
# r0058Racial descriptor
# r0058Country marks
# r0058Destination (region)
# r0058Ran from specified
# r0058Origin
# r0058Plantation marks
# r0058Name of contact
# r0058Owner
# r0058Skills
# r0058Disease
# r0058Physical scars
# r0058Clothing
# r0058Accused of crime
# r0058Personality
# r0058Given surname
# r0058Also known as
# r0058Total reward
# r0058Ran from region
# r0058Owner address
# r0058Destination (specified)
# r0058Language
# r0058Other reward
# r0058Motivation
# r0058Literacy
# r0058Runaway date
# r0058Specified occupation
# r0058Given name
# r0058Religion
# r0058Physical characteristics
# r0058Companions
# r0058Contact occupation
# r0059Injuries
# r0059Stutters
# r0059Owner occupation
# r0059Contact address
# r0059Racial descriptor
# r0059Country marks
# r0059Destination (region)
# r0059Ran from specified
# r0059Origin
# r0059Plantation marks
# r0059Name of contact
# r0059Owner
# r0059Skills
# r0059Disease
# r0059Physical scars
# r0059Clothing
# r0059Accused of crime
# r0059Personality
# r0059Given surname
# r0059Also known as
# r0059Total reward
# r0059Ran from region
# r0059Owner address
# r0059Destination (specified)
# r0059Language
# r0059Other reward
# r0059Motivation
# r0059Literacy
# r0059Runaway date
# r0059Specified occupation
# r0059Given name
# r0059Religion
# r0059Physical characteristics
# r0059Companions
# r0059Contact occupation
# r0060Injuries
# r0060Stutters
# r0060Owner occupation
# r0060Contact address
# r0060Racial descriptor
# r0060Country marks
# r0060Destination (region)
# r0060Ran from specified
# r0060Origin
# r0060Plantation marks
# r0060Name of contact
# r0060Owner
# r0060Skills
# r0060Disease
# r0060Physical scars
# r0060Clothing
# r0060Accused of crime
# r0060Personality
# r0060Given surname
# r0060Also known as
# r0060Total reward
# r0060Ran from region
# r0060Owner address
# r0060Destination (specified)
# r0060Language
# r0060Other reward
# r0060Motivation
# r0060Literacy
# r0060Runaway date
# r0060Specified occupation
# r0060Given name
# r0060Religion
# r0060Physical characteristics
# r0060Companions
# r0060Contact occupation
# r0062Injuries
# r0062Stutters
# r0062Owner occupation
# r0062Contact address
# r0062Racial descriptor
# r0062Country marks
# r0062Destination (region)
# r0062Ran from specified
# r0062Origin
# r0062Plantation marks
# r0062Name of contact
# r0062Owner
# r0062Skills
# r0062Disease
# r0062Physical scars
# r0062Clothing
# r0062Accused of crime
# r0062Personality
# r0062Given surname
# r0062Also known as
# r0062Total reward
# r0062Ran from region
# r0062Owner address
# r0062Destination (specified)
# r0062Language
# r0062Other reward
# r0062Motivation
# r0062Literacy
# r0062Runaway date
# r0062Specified occupation
# r0062Given name
# r0062Religion
# r0062Physical characteristics
# r0062Companions
# r0062Contact occupation
# r0064Injuries
# r0064Stutters
# r0064Owner occupation
# r0064Contact address
# r0064Racial descriptor
# r0064Country marks
# r0064Destination (region)
# r0064Ran from specified
# r0064Origin
# r0064Plantation marks
# r0064Name of contact
# r0064Owner
# r0064Skills
# r0064Disease
# r0064Physical scars
# r0064Clothing
# r0064Accused of crime
# r0064Personality
# r0064Given surname
# r0064Also known as
# r0064Total reward
# r0064Ran from region
# r0064Owner address
# r0064Destination (specified)
# r0064Language
# r0064Other reward
# r0064Motivation
# r0064Literacy
# r0064Runaway date
# r0064Specified occupation
# r0064Given name
# r0064Religion
# r0064Physical characteristics
# r0064Companions
# r0064Contact occupation
# r0066Injuries
# r0066Stutters
# r0066Owner occupation
# r0066Contact address
# r0066Racial descriptor
# r0066Country marks
# r0066Destination (region)
# r0066Ran from specified
# r0066Origin
# r0066Plantation marks
# r0066Name of contact
# r0066Owner
# r0066Skills
# r0066Disease
# r0066Physical scars
# r0066Clothing
# r0066Accused of crime
# r0066Personality
# r0066Given surname
# r0066Also known as
# r0066Total reward
# r0066Ran from region
# r0066Owner address
# r0066Destination (specified)
# r0066Language
# r0066Other reward
# r0066Motivation
# r0066Literacy
# r0066Runaway date
# r0066Specified occupation
# r0066Given name
# r0066Religion
# r0066Physical characteristics
# r0066Companions
# r0066Contact occupation
# r0067Injuries
# r0067Stutters
# r0067Owner occupation
# r0067Contact address
# r0067Racial descriptor
# r0067Country marks
# r0067Destination (region)
# r0067Ran from specified
# r0067Origin
# r0067Plantation marks
# r0067Name of contact
# r0067Owner
# r0067Skills
# r0067Disease
# r0067Physical scars
# r0067Clothing
# r0067Accused of crime
# r0067Personality
# r0067Given surname
# r0067Also known as
# r0067Total reward
# r0067Ran from region
# r0067Owner address
# r0067Destination (specified)
# r0067Language
# r0067Other reward
# r0067Motivation
# r0067Literacy
# r0067Runaway date
# r0067Specified occupation
# r0067Given name
# r0067Religion
# r0067Physical characteristics
# r0067Companions
# r0067Contact occupation
# r0068Injuries
# r0068Stutters
# r0068Owner occupation
# r0068Contact address
# r0068Racial descriptor
# r0068Country marks
# r0068Destination (region)
# r0068Ran from specified
# r0068Origin
# r0068Plantation marks
# r0068Name of contact
# r0068Owner
# r0068Skills
# r0068Disease
# r0068Physical scars
# r0068Clothing
# r0068Accused of crime
# r0068Personality
# r0068Given surname
# r0068Also known as
# r0068Total reward
# r0068Ran from region
# r0068Owner address
# r0068Destination (specified)
# r0068Language
# r0068Other reward
# r0068Motivation
# r0068Literacy
# r0068Runaway date
# r0068Specified occupation
# r0068Given name
# r0068Religion
# r0068Physical characteristics
# r0068Companions
# r0068Contact occupation
# r0069Injuries
# r0069Stutters
# r0069Owner occupation
# r0069Contact address
# r0069Racial descriptor
# r0069Country marks
# r0069Destination (region)
# r0069Ran from specified
# r0069Origin
# r0069Plantation marks
# r0069Name of contact
# r0069Owner
# r0069Skills
# r0069Disease
# r0069Physical scars
# r0069Clothing
# r0069Accused of crime
# r0069Personality
# r0069Given surname
# r0069Also known as
# r0069Total reward
# r0069Ran from region
# r0069Owner address
# r0069Destination (specified)
# r0069Language
# r0069Other reward
# r0069Motivation
# r0069Literacy
# r0069Runaway date
# r0069Specified occupation
# r0069Given name
# r0069Religion
# r0069Physical characteristics
# r0069Companions
# r0069Contact occupation
# r0070Injuries
# r0070Stutters
# r0070Owner occupation
# r0070Contact address
# r0070Racial descriptor
# r0070Country marks
# r0070Destination (region)
# r0070Ran from specified
# r0070Origin
# r0070Plantation marks
# r0070Name of contact
# r0070Owner
# r0070Skills
# r0070Disease
# r0070Physical scars
# r0070Clothing
# r0070Accused of crime
# r0070Personality
# r0070Given surname
# r0070Also known as
# r0070Total reward
# r0070Ran from region
# r0070Owner address
# r0070Destination (specified)
# r0070Language
# r0070Other reward
# r0070Motivation
# r0070Literacy
# r0070Runaway date
# r0070Specified occupation
# r0070Given name
# r0070Religion
# r0070Physical characteristics
# r0070Companions
# r0070Contact occupation
# r0071Injuries
# r0071Stutters
# r0071Owner occupation
# r0071Contact address
# r0071Racial descriptor
# r0071Country marks
# r0071Destination (region)
# r0071Ran from specified
# r0071Origin
# r0071Plantation marks
# r0071Name of contact
# r0071Owner
# r0071Skills
# r0071Disease
# r0071Physical scars
# r0071Clothing
# r0071Accused of crime
# r0071Personality
# r0071Given surname
# r0071Also known as
# r0071Total reward
# r0071Ran from region
# r0071Owner address
# r0071Destination (specified)
# r0071Language
# r0071Other reward
# r0071Motivation
# r0071Literacy
# r0071Runaway date
# r0071Specified occupation
# r0071Given name
# r0071Religion
# r0071Physical characteristics
# r0071Companions
# r0071Contact occupation
# r0072Injuries
# r0072Stutters
# r0072Owner occupation
# r0072Contact address
# r0072Racial descriptor
# r0072Country marks
# r0072Destination (region)
# r0072Ran from specified
# r0072Origin
# r0072Plantation marks
# r0072Name of contact
# r0072Owner
# r0072Skills
# r0072Disease
# r0072Physical scars
# r0072Clothing
# r0072Accused of crime
# r0072Personality
# r0072Given surname
# r0072Also known as
# r0072Total reward
# r0072Ran from region
# r0072Owner address
# r0072Destination (specified)
# r0072Language
# r0072Other reward
# r0072Motivation
# r0072Literacy
# r0072Runaway date
# r0072Specified occupation
# r0072Given name
# r0072Religion
# r0072Physical characteristics
# r0072Companions
# r0072Contact occupation
# r0073Injuries
# r0073Stutters
# r0073Owner occupation
# r0073Contact address
# r0073Racial descriptor
# r0073Country marks
# r0073Destination (region)
# r0073Ran from specified
# r0073Origin
# r0073Plantation marks
# r0073Name of contact
# r0073Owner
# r0073Skills
# r0073Disease
# r0073Physical scars
# r0073Clothing
# r0073Accused of crime
# r0073Personality
# r0073Given surname
# r0073Also known as
# r0073Total reward
# r0073Ran from region
# r0073Owner address
# r0073Destination (specified)
# r0073Language
# r0073Other reward
# r0073Motivation
# r0073Literacy
# r0073Runaway date
# r0073Specified occupation
# r0073Given name
# r0073Religion
# r0073Physical characteristics
# r0073Companions
# r0073Contact occupation
# r0074Injuries
# r0074Stutters
# r0074Owner occupation
# r0074Contact address
# r0074Racial descriptor
# r0074Country marks
# r0074Destination (region)
# r0074Ran from specified
# r0074Origin
# r0074Plantation marks
# r0074Name of contact
# r0074Owner
# r0074Skills
# r0074Disease
# r0074Physical scars
# r0074Clothing
# r0074Accused of crime
# r0074Personality
# r0074Given surname
# r0074Also known as
# r0074Total reward
# r0074Ran from region
# r0074Owner address
# r0074Destination (specified)
# r0074Language
# r0074Other reward
# r0074Motivation
# r0074Literacy
# r0074Runaway date
# r0074Specified occupation
# r0074Given name
# r0074Religion
# r0074Physical characteristics
# r0074Companions
# r0074Contact occupation
# r0075Injuries
# r0075Stutters
# r0075Owner occupation
# r0075Contact address
# r0075Racial descriptor
# r0075Country marks
# r0075Destination (region)
# r0075Ran from specified
# r0075Origin
# r0075Plantation marks
# r0075Name of contact
# r0075Owner
# r0075Skills
# r0075Disease
# r0075Physical scars
# r0075Clothing
# r0075Accused of crime
# r0075Personality
# r0075Given surname
# r0075Also known as
# r0075Total reward
# r0075Ran from region
# r0075Owner address
# r0075Destination (specified)
# r0075Language
# r0075Other reward
# r0075Motivation
# r0075Literacy
# r0075Runaway date
# r0075Specified occupation
# r0075Given name
# r0075Religion
# r0075Physical characteristics
# r0075Companions
# r0075Contact occupation
# r0076Injuries
# r0076Stutters
# r0076Owner occupation
# r0076Contact address
# r0076Racial descriptor
# r0076Country marks
# r0076Destination (region)
# r0076Ran from specified
# r0076Origin
# r0076Plantation marks
# r0076Name of contact
# r0076Owner
# r0076Skills
# r0076Disease
# r0076Physical scars
# r0076Clothing
# r0076Accused of crime
# r0076Personality
# r0076Given surname
# r0076Also known as
# r0076Total reward
# r0076Ran from region
# r0076Owner address
# r0076Destination (specified)
# r0076Language
# r0076Other reward
# r0076Motivation
# r0076Literacy
# r0076Runaway date
# r0076Specified occupation
# r0076Given name
# r0076Religion
# r0076Physical characteristics
# r0076Companions
# r0076Contact occupation
# r0077Injuries
# r0077Stutters
# r0077Owner occupation
# r0077Contact address
# r0077Racial descriptor
# r0077Country marks
# r0077Destination (region)
# r0077Ran from specified
# r0077Origin
# r0077Plantation marks
# r0077Name of contact
# r0077Owner
# r0077Skills
# r0077Disease
# r0077Physical scars
# r0077Clothing
# r0077Accused of crime
# r0077Personality
# r0077Given surname
# r0077Also known as
# r0077Total reward
# r0077Ran from region
# r0077Owner address
# r0077Destination (specified)
# r0077Language
# r0077Other reward
# r0077Motivation
# r0077Literacy
# r0077Runaway date
# r0077Specified occupation
# r0077Given name
# r0077Religion
# r0077Physical characteristics
# r0077Companions
# r0077Contact occupation
# r0079Injuries
# r0079Stutters
# r0079Owner occupation
# r0079Contact address
# r0079Racial descriptor
# r0079Country marks
# r0079Destination (region)
# r0079Ran from specified
# r0079Origin
# r0079Plantation marks
# r0079Name of contact
# r0079Owner
# r0079Skills
# r0079Disease
# r0079Physical scars
# r0079Clothing
# r0079Accused of crime
# r0079Personality
# r0079Given surname
# r0079Also known as
# r0079Total reward
# r0079Ran from region
# r0079Owner address
# r0079Destination (specified)
# r0079Language
# r0079Other reward
# r0079Motivation
# r0079Literacy
# r0079Runaway date
# r0079Specified occupation
# r0079Given name
# r0079Religion
# r0079Physical characteristics
# r0079Companions
# r0079Contact occupation
# r0080Injuries
# r0080Stutters
# r0080Owner occupation
# r0080Contact address
# r0080Racial descriptor
# r0080Country marks
# r0080Destination (region)
# r0080Ran from specified
# r0080Origin
# r0080Plantation marks
# r0080Name of contact
# r0080Owner
# r0080Skills
# r0080Disease
# r0080Physical scars
# r0080Clothing
# r0080Accused of crime
# r0080Personality
# r0080Given surname
# r0080Also known as
# r0080Total reward
# r0080Ran from region
# r0080Owner address
# r0080Destination (specified)
# r0080Language
# r0080Other reward
# r0080Motivation
# r0080Literacy
# r0080Runaway date
# r0080Specified occupation
# r0080Given name
# r0080Religion
# r0080Physical characteristics
# r0080Companions
# r0080Contact occupation
# r0081Injuries
# r0081Stutters
# r0081Owner occupation
# r0081Contact address
# r0081Racial descriptor
# r0081Country marks
# r0081Destination (region)
# r0081Ran from specified
# r0081Origin
# r0081Plantation marks
# r0081Name of contact
# r0081Owner
# r0081Skills
# r0081Disease
# r0081Physical scars
# r0081Clothing
# r0081Accused of crime
# r0081Personality
# r0081Given surname
# r0081Also known as
# r0081Total reward
# r0081Ran from region
# r0081Owner address
# r0081Destination (specified)
# r0081Language
# r0081Other reward
# r0081Motivation
# r0081Literacy
# r0081Runaway date
# r0081Specified occupation
# r0081Given name
# r0081Religion
# r0081Physical characteristics
# r0081Companions
# r0081Contact occupation
# r0082Injuries
# r0082Stutters
# r0082Owner occupation
# r0082Contact address
# r0082Racial descriptor
# r0082Country marks
# r0082Destination (region)
# r0082Ran from specified
# r0082Origin
# r0082Plantation marks
# r0082Name of contact
# r0082Owner
# r0082Skills
# r0082Disease
# r0082Physical scars
# r0082Clothing
# r0082Accused of crime
# r0082Personality
# r0082Given surname
# r0082Also known as
# r0082Total reward
# r0082Ran from region
# r0082Owner address
# r0082Destination (specified)
# r0082Language
# r0082Other reward
# r0082Motivation
# r0082Literacy
# r0082Runaway date
# r0082Specified occupation
# r0082Given name
# r0082Religion
# r0082Physical characteristics
# r0082Companions
# r0082Contact occupation
# r0085Injuries
# r0085Stutters
# r0085Owner occupation
# r0085Contact address
# r0085Racial descriptor
# r0085Country marks
# r0085Destination (region)
# r0085Ran from specified
# r0085Origin
# r0085Plantation marks
# r0085Name of contact
# r0085Owner
# r0085Skills
# r0085Disease
# r0085Physical scars
# r0085Clothing
# r0085Accused of crime
# r0085Personality
# r0085Given surname
# r0085Also known as
# r0085Total reward
# r0085Ran from region
# r0085Owner address
# r0085Destination (specified)
# r0085Language
# r0085Other reward
# r0085Motivation
# r0085Literacy
# r0085Runaway date
# r0085Specified occupation
# r0085Given name
# r0085Religion
# r0085Physical characteristics
# r0085Companions
# r0085Contact occupation
# r0086Injuries
# r0086Stutters
# r0086Owner occupation
# r0086Contact address
# r0086Racial descriptor
# r0086Country marks
# r0086Destination (region)
# r0086Ran from specified
# r0086Origin
# r0086Plantation marks
# r0086Name of contact
# r0086Owner
# r0086Skills
# r0086Disease
# r0086Physical scars
# r0086Clothing
# r0086Accused of crime
# r0086Personality
# r0086Given surname
# r0086Also known as
# r0086Total reward
# r0086Ran from region
# r0086Owner address
# r0086Destination (specified)
# r0086Language
# r0086Other reward
# r0086Motivation
# r0086Literacy
# r0086Runaway date
# r0086Specified occupation
# r0086Given name
# r0086Religion
# r0086Physical characteristics
# r0086Companions
# r0086Contact occupation
# r0087Injuries
# r0087Stutters
# r0087Owner occupation
# r0087Contact address
# r0087Racial descriptor
# r0087Country marks
# r0087Destination (region)
# r0087Ran from specified
# r0087Origin
# r0087Plantation marks
# r0087Name of contact
# r0087Owner
# r0087Skills
# r0087Disease
# r0087Physical scars
# r0087Clothing
# r0087Accused of crime
# r0087Personality
# r0087Given surname
# r0087Also known as
# r0087Total reward
# r0087Ran from region
# r0087Owner address
# r0087Destination (specified)
# r0087Language
# r0087Other reward
# r0087Motivation
# r0087Literacy
# r0087Runaway date
# r0087Specified occupation
# r0087Given name
# r0087Religion
# r0087Physical characteristics
# r0087Companions
# r0087Contact occupation
# r0088Injuries
# r0088Stutters
# r0088Owner occupation
# r0088Contact address
# r0088Racial descriptor
# r0088Country marks
# r0088Destination (region)
# r0088Ran from specified
# r0088Origin
# r0088Plantation marks
# r0088Name of contact
# r0088Owner
# r0088Skills
# r0088Disease
# r0088Physical scars
# r0088Clothing
# r0088Accused of crime
# r0088Personality
# r0088Given surname
# r0088Also known as
# r0088Total reward
# r0088Ran from region
# r0088Owner address
# r0088Destination (specified)
# r0088Language
# r0088Other reward
# r0088Motivation
# r0088Literacy
# r0088Runaway date
# r0088Specified occupation
# r0088Given name
# r0088Religion
# r0088Physical characteristics
# ...
# r0808Motivation
# r0808Literacy
# r0808Runaway date
# r0808Specified occupation
# r0808Given name
# r0808Religion
# r0808Physical characteristics
# r0808Companions
# r0808Contact occupation
# r0809Injuries
# r0809Stutters
# r0809Owner occupation
# r0809Contact address
# r0809Racial descriptor
# r0809Country marks
# r0809Destination (region)
# r0809Ran from specified
# r0809Origin
# r0809Plantation marks
# r0809Name of contact
# r0809Owner
# r0809Skills
# r0809Disease
# r0809Physical scars
# r0809Clothing
# r0809Accused of crime
# r0809Personality
# r0809Given surname
# r0809Also known as
# r0809Total reward
# r0809Ran from region
# r0809Owner address
# r0809Destination (specified)
# r0809Language
# r0809Other reward
# r0809Motivation
# r0809Literacy
# r0809Runaway date
# r0809Specified occupation
# r0809Given name
# r0809Religion
# r0809Physical characteristics
# r0809Companions
# r0809Contact occupation
# r0811Injuries
# r0811Stutters
# r0811Owner occupation
# r0811Contact address
# r0811Racial descriptor
# r0811Country marks
# r0811Destination (region)
# r0811Ran from specified
# r0811Origin
# r0811Plantation marks
# r0811Name of contact
# r0811Owner
# r0811Skills
# r0811Disease
# r0811Physical scars
# r0811Clothing
# r0811Accused of crime
# r0811Personality
# r0811Given surname
# r0811Also known as
# r0811Total reward
# r0811Ran from region
# r0811Owner address
# r0811Destination (specified)
# r0811Language
# r0811Other reward
# r0811Motivation
# r0811Literacy
# r0811Runaway date
# r0811Specified occupation
# r0811Given name
# r0811Religion
# r0811Physical characteristics
# r0811Companions
# r0811Contact occupation
# r0812Injuries
# r0812Stutters
# r0812Owner occupation
# r0812Contact address
# r0812Racial descriptor
# r0812Country marks
# r0812Destination (region)
# r0812Ran from specified
# r0812Origin
# r0812Plantation marks
# r0812Name of contact
# r0812Owner
# r0812Skills
# r0812Disease
# r0812Physical scars
# r0812Clothing
# r0812Accused of crime
# r0812Personality
# r0812Given surname
# r0812Also known as
# r0812Total reward
# r0812Ran from region
# r0812Owner address
# r0812Destination (specified)
# r0812Language
# r0812Other reward
# r0812Motivation
# r0812Literacy
# r0812Runaway date
# r0812Specified occupation
# r0812Given name
# r0812Religion
# r0812Physical characteristics
# r0812Companions
# r0812Contact occupation
# r0813Injuries
# r0813Stutters
# r0813Owner occupation
# r0813Contact address
# r0813Racial descriptor
# r0813Country marks
# r0813Destination (region)
# r0813Ran from specified
# r0813Origin
# r0813Plantation marks
# r0813Name of contact
# r0813Owner
# r0813Skills
# r0813Disease
# r0813Physical scars
# r0813Clothing
# r0813Accused of crime
# r0813Personality
# r0813Given surname
# r0813Also known as
# r0813Total reward
# r0813Ran from region
# r0813Owner address
# r0813Destination (specified)
# r0813Language
# r0813Other reward
# r0813Motivation
# r0813Literacy
# r0813Runaway date
# r0813Specified occupation
# r0813Given name
# r0813Religion
# r0813Physical characteristics
# r0813Companions
# r0813Contact occupation
# r0814Injuries
# r0814Stutters
# r0814Owner occupation
# r0814Contact address
# r0814Racial descriptor
# r0814Country marks
# r0814Destination (region)
# r0814Ran from specified
# r0814Origin
# r0814Plantation marks
# r0814Name of contact
# r0814Owner
# r0814Skills
# r0814Disease
# r0814Physical scars
# r0814Clothing
# r0814Accused of crime
# r0814Personality
# r0814Given surname
# r0814Also known as
# r0814Total reward
# r0814Ran from region
# r0814Owner address
# r0814Destination (specified)
# r0814Language
# r0814Other reward
# r0814Motivation
# r0814Literacy
# r0814Runaway date
# r0814Specified occupation
# r0814Given name
# r0814Religion
# r0814Physical characteristics
# r0814Companions
# r0814Contact occupation
# r0815Injuries
# r0815Stutters
# r0815Owner occupation
# r0815Contact address
# r0815Racial descriptor
# r0815Country marks
# r0815Destination (region)
# r0815Ran from specified
# r0815Origin
# r0815Plantation marks
# r0815Name of contact
# r0815Owner
# r0815Skills
# r0815Disease
# r0815Physical scars
# r0815Clothing
# r0815Accused of crime
# r0815Personality
# r0815Given surname
# r0815Also known as
# r0815Total reward
# r0815Ran from region
# r0815Owner address
# r0815Destination (specified)
# r0815Language
# r0815Other reward
# r0815Motivation
# r0815Literacy
# r0815Runaway date
# r0815Specified occupation
# r0815Given name
# r0815Religion
# r0815Physical characteristics
# r0815Companions
# r0815Contact occupation
# r0817Injuries
# r0817Stutters
# r0817Owner occupation
# r0817Contact address
# r0817Racial descriptor
# r0817Country marks
# r0817Destination (region)
# r0817Ran from specified
# r0817Origin
# r0817Plantation marks
# r0817Name of contact
# r0817Owner
# r0817Skills
# r0817Disease
# r0817Physical scars
# r0817Clothing
# r0817Accused of crime
# r0817Personality
# r0817Given surname
# r0817Also known as
# r0817Total reward
# r0817Ran from region
# r0817Owner address
# r0817Destination (specified)
# r0817Language
# r0817Other reward
# r0817Motivation
# r0817Literacy
# r0817Runaway date
# r0817Specified occupation
# r0817Given name
# r0817Religion
# r0817Physical characteristics
# r0817Companions
# r0817Contact occupation
# r0818Injuries
# r0818Stutters
# r0818Owner occupation
# r0818Contact address
# r0818Racial descriptor
# r0818Country marks
# r0818Destination (region)
# r0818Ran from specified
# r0818Origin
# r0818Plantation marks
# r0818Name of contact
# r0818Owner
# r0818Skills
# r0818Disease
# r0818Physical scars
# r0818Clothing
# r0818Accused of crime
# r0818Personality
# r0818Given surname
# r0818Also known as
# r0818Total reward
# r0818Ran from region
# r0818Owner address
# r0818Destination (specified)
# r0818Language
# r0818Other reward
# r0818Motivation
# r0818Literacy
# r0818Runaway date
# r0818Specified occupation
# r0818Given name
# r0818Religion
# r0818Physical characteristics
# r0818Companions
# r0818Contact occupation
# r0819Injuries
# r0819Stutters
# r0819Owner occupation
# r0819Contact address
# r0819Racial descriptor
# r0819Country marks
# r0819Destination (region)
# r0819Ran from specified
# r0819Origin
# r0819Plantation marks
# r0819Name of contact
# r0819Owner
# r0819Skills
# r0819Disease
# r0819Physical scars
# r0819Clothing
# r0819Accused of crime
# r0819Personality
# r0819Given surname
# r0819Also known as
# r0819Total reward
# r0819Ran from region
# r0819Owner address
# r0819Destination (specified)
# r0819Language
# r0819Other reward
# r0819Motivation
# r0819Literacy
# r0819Runaway date
# r0819Specified occupation
# r0819Given name
# r0819Religion
# r0819Physical characteristics
# r0819Companions
# r0819Contact occupation
# r0822Injuries
# r0822Stutters
# r0822Owner occupation
# r0822Contact address
# r0822Racial descriptor
# r0822Country marks
# r0822Destination (region)
# r0822Ran from specified
# r0822Origin
# r0822Plantation marks
# r0822Name of contact
# r0822Owner
# r0822Skills
# r0822Disease
# r0822Physical scars
# r0822Clothing
# r0822Accused of crime
# r0822Personality
# r0822Given surname
# r0822Also known as
# r0822Total reward
# r0822Ran from region
# r0822Owner address
# r0822Destination (specified)
# r0822Language
# r0822Other reward
# r0822Motivation
# r0822Literacy
# r0822Runaway date
# r0822Specified occupation
# r0822Given name
# r0822Religion
# r0822Physical characteristics
# r0822Companions
# r0822Contact occupation
# r0824Injuries
# r0824Stutters
# r0824Owner occupation
# r0824Contact address
# r0824Racial descriptor
# r0824Country marks
# r0824Destination (region)
# r0824Ran from specified
# r0824Origin
# r0824Plantation marks
# r0824Name of contact
# r0824Owner
# r0824Skills
# r0824Disease
# r0824Physical scars
# r0824Clothing
# r0824Accused of crime
# r0824Personality
# r0824Given surname
# r0824Also known as
# r0824Total reward
# r0824Ran from region
# r0824Owner address
# r0824Destination (specified)
# r0824Language
# r0824Other reward
# r0824Motivation
# r0824Literacy
# r0824Runaway date
# r0824Specified occupation
# r0824Given name
# r0824Religion
# r0824Physical characteristics
# r0824Companions
# r0824Contact occupation
# r0825Injuries
# r0825Stutters
# r0825Owner occupation
# r0825Contact address
# r0825Racial descriptor
# r0825Country marks
# r0825Destination (region)
# r0825Ran from specified
# r0825Origin
# r0825Plantation marks
# r0825Name of contact
# r0825Owner
# r0825Skills
# r0825Disease
# r0825Physical scars
# r0825Clothing
# r0825Accused of crime
# r0825Personality
# r0825Given surname
# r0825Also known as
# r0825Total reward
# r0825Ran from region
# r0825Owner address
# r0825Destination (specified)
# r0825Language
# r0825Other reward
# r0825Motivation
# r0825Literacy
# r0825Runaway date
# r0825Specified occupation
# r0825Given name
# r0825Religion
# r0825Physical characteristics
# r0825Companions
# r0825Contact occupation
# r0826Injuries
# r0826Stutters
# r0826Owner occupation
# r0826Contact address
# r0826Racial descriptor
# r0826Country marks
# r0826Destination (region)
# r0826Ran from specified
# r0826Origin
# r0826Plantation marks
# r0826Name of contact
# r0826Owner
# r0826Skills
# r0826Disease
# r0826Physical scars
# r0826Clothing
# r0826Accused of crime
# r0826Personality
# r0826Given surname
# r0826Also known as
# r0826Total reward
# r0826Ran from region
# r0826Owner address
# r0826Destination (specified)
# r0826Language
# r0826Other reward
# r0826Motivation
# r0826Literacy
# r0826Runaway date
# r0826Specified occupation
# r0826Given name
# r0826Religion
# r0826Physical characteristics
# r0826Companions
# r0826Contact occupation
# r0828Injuries
# r0828Stutters
# r0828Owner occupation
# r0828Contact address
# r0828Racial descriptor
# r0828Country marks
# r0828Destination (region)
# r0828Ran from specified
# r0828Origin
# r0828Plantation marks
# r0828Name of contact
# r0828Owner
# r0828Skills
# r0828Disease
# r0828Physical scars
# r0828Clothing
# r0828Accused of crime
# r0828Personality
# r0828Given surname
# r0828Also known as
# r0828Total reward
# r0828Ran from region
# r0828Owner address
# r0828Destination (specified)
# r0828Language
# r0828Other reward
# r0828Motivation
# r0828Literacy
# r0828Runaway date
# r0828Specified occupation
# r0828Given name
# r0828Religion
# r0828Physical characteristics
# r0828Companions
# r0828Contact occupation
# r0829Injuries
# r0829Stutters
# r0829Owner occupation
# r0829Contact address
# r0829Racial descriptor
# r0829Country marks
# r0829Destination (region)
# r0829Ran from specified
# r0829Origin
# r0829Plantation marks
# r0829Name of contact
# r0829Owner
# r0829Skills
# r0829Disease
# r0829Physical scars
# r0829Clothing
# r0829Accused of crime
# r0829Personality
# r0829Given surname
# r0829Also known as
# r0829Total reward
# r0829Ran from region
# r0829Owner address
# r0829Destination (specified)
# r0829Language
# r0829Other reward
# r0829Motivation
# r0829Literacy
# r0829Runaway date
# r0829Specified occupation
# r0829Given name
# r0829Religion
# r0829Physical characteristics
# r0829Companions
# r0829Contact occupation
# r0830Injuries
# r0830Stutters
# r0830Owner occupation
# r0830Contact address
# r0830Racial descriptor
# r0830Country marks
# r0830Destination (region)
# r0830Ran from specified
# r0830Origin
# r0830Plantation marks
# r0830Name of contact
# r0830Owner
# r0830Skills
# r0830Disease
# r0830Physical scars
# r0830Clothing
# r0830Accused of crime
# r0830Personality
# r0830Given surname
# r0830Also known as
# r0830Total reward
# r0830Ran from region
# r0830Owner address
# r0830Destination (specified)
# r0830Language
# r0830Other reward
# r0830Motivation
# r0830Literacy
# r0830Runaway date
# r0830Specified occupation
# r0830Given name
# r0830Religion
# r0830Physical characteristics
# r0830Companions
# r0830Contact occupation
# r0831Injuries
# r0831Stutters
# r0831Owner occupation
# r0831Contact address
# r0831Racial descriptor
# r0831Country marks
# r0831Destination (region)
# r0831Ran from specified
# r0831Origin
# r0831Plantation marks
# r0831Name of contact
# r0831Owner
# r0831Skills
# r0831Disease
# r0831Physical scars
# r0831Clothing
# r0831Accused of crime
# r0831Personality
# r0831Given surname
# r0831Also known as
# r0831Total reward
# r0831Ran from region
# r0831Owner address
# r0831Destination (specified)
# r0831Language
# r0831Other reward
# r0831Motivation
# r0831Literacy
# r0831Runaway date
# r0831Specified occupation
# r0831Given name
# r0831Religion
# r0831Physical characteristics
# r0831Companions
# r0831Contact occupation
# r0832Injuries
# r0832Stutters
# r0832Owner occupation
# r0832Contact address
# r0832Racial descriptor
# r0832Country marks
# r0832Destination (region)
# r0832Ran from specified
# r0832Origin
# r0832Plantation marks
# r0832Name of contact
# r0832Owner
# r0832Skills
# r0832Disease
# r0832Physical scars
# r0832Clothing
# r0832Accused of crime
# r0832Personality
# r0832Given surname
# r0832Also known as
# r0832Total reward
# r0832Ran from region
# r0832Owner address
# r0832Destination (specified)
# r0832Language
# r0832Other reward
# r0832Motivation
# r0832Literacy
# r0832Runaway date
# r0832Specified occupation
# r0832Given name
# r0832Religion
# r0832Physical characteristics
# r0832Companions
# r0832Contact occupation
# r0833Injuries
# r0833Stutters
# r0833Owner occupation
# r0833Contact address
# r0833Racial descriptor
# r0833Country marks
# r0833Destination (region)
# r0833Ran from specified
# r0833Origin
# r0833Plantation marks
# r0833Name of contact
# r0833Owner
# r0833Skills
# r0833Disease
# r0833Physical scars
# r0833Clothing
# r0833Accused of crime
# r0833Personality
# r0833Given surname
# r0833Also known as
# r0833Total reward
# r0833Ran from region
# r0833Owner address
# r0833Destination (specified)
# r0833Language
# r0833Other reward
# r0833Motivation
# r0833Literacy
# r0833Runaway date
# r0833Specified occupation
# r0833Given name
# r0833Religion
# r0833Physical characteristics
# r0833Companions
# r0833Contact occupation
# r0834Injuries
# r0834Stutters
# r0834Owner occupation
# r0834Contact address
# r0834Racial descriptor
# r0834Country marks
# r0834Destination (region)
# r0834Ran from specified
# r0834Origin
# r0834Plantation marks
# r0834Name of contact
# r0834Owner
# r0834Skills
# r0834Disease
# r0834Physical scars
# r0834Clothing
# r0834Accused of crime
# r0834Personality
# r0834Given surname
# r0834Also known as
# r0834Total reward
# r0834Ran from region
# r0834Owner address
# r0834Destination (specified)
# r0834Language
# r0834Other reward
# r0834Motivation
# r0834Literacy
# r0834Runaway date
# r0834Specified occupation
# r0834Given name
# r0834Religion
# r0834Physical characteristics
# r0834Companions
# r0834Contact occupation
# r0835Injuries
# r0835Stutters
# r0835Owner occupation
# r0835Contact address
# r0835Racial descriptor
# r0835Country marks
# r0835Destination (region)
# r0835Ran from specified
# r0835Origin
# r0835Plantation marks
# r0835Name of contact
# r0835Owner
# r0835Skills
# r0835Disease
# r0835Physical scars
# r0835Clothing
# r0835Accused of crime
# r0835Personality
# r0835Given surname
# r0835Also known as
# r0835Total reward
# r0835Ran from region
# r0835Owner address
# r0835Destination (specified)
# r0835Language
# r0835Other reward
# r0835Motivation
# r0835Literacy
# r0835Runaway date
# r0835Specified occupation
# r0835Given name
# r0835Religion
# r0835Physical characteristics
# r0835Companions
# r0835Contact occupation
# r0836Injuries
# r0836Stutters
# r0836Owner occupation
# r0836Contact address
# r0836Racial descriptor
# r0836Country marks
# r0836Destination (region)
# r0836Ran from specified
# r0836Origin
# r0836Plantation marks
# r0836Name of contact
# r0836Owner
# r0836Skills
# r0836Disease
# r0836Physical scars
# r0836Clothing
# r0836Accused of crime
# r0836Personality
# r0836Given surname
# r0836Also known as
# r0836Total reward
# r0836Ran from region
# r0836Owner address
# r0836Destination (specified)
# r0836Language
# r0836Other reward
# r0836Motivation
# r0836Literacy
# r0836Runaway date
# r0836Specified occupation
# r0836Given name
# r0836Religion
# r0836Physical characteristics
# r0836Companions
# r0836Contact occupation
# r0477Name of contact
# r0478Contact address
# r0478Name of contact
# r0495Contact address
# r0497Contact address
# r0497Contact address
# r0497Contact address
# r0497Name of contact
# r0497Name of contact
# r0497Name of contact
# r0497Contact occupation
# r0509Contact address
# r0509Name of contact
# r0510Contact address
# r0510Name of contact
# r0513Contact address
# r0524Contact address
# r0524Name of contact
# r0533Contact address
# r0533Name of contact
# r0534Contact address
# r0534Name of contact
# r0535Contact address
# r0535Name of contact
# r0540Contact address
# r0540Name of contact
# r0544Name of contact
# r0544Contact occupation
# r0556Contact address
# r0556Name of contact
# r0557Contact address
# r0557Name of contact
# r0557Contact occupation
# r0567Contact address
# r0567Name of contact
# r0567Contact occupation
# r0577Name of contact
# r0577Contact occupation
# r0587Contact address
# r0587Contact address
# r0587Name of contact
# r0587Name of contact
# r0591Contact address
# r0591Name of contact
# r0662Contact address
# r0662Name of contact
# r0786Specified occupation
# r0786Specified occupation
# r0788Contact address
# r0788Contact address
# r0788Name of contact
# r0788Name of contact
# r0792Clothing
# r0792Physical characteristics
# r0808Total reward
# r0811Clothing
# r0811Clothing
# r0812Contact address
# r0812Name of contact
# r0813Contact address
# r0813Name of contact
# r0817Contact address
# r0817Name of contact

# %%
dataset_root_path = "/projects/copenlu/data/nadav/Datasets/pixel_squad_cannon/"

test_images = glob(f"{dataset_root_path}/test/images/*.png")
test_labels = [path.replace("images", "labels").replace(".png", ".npy") for path in test_images]


test_labels = [np.load(l) for l in test_labels]
test_dataset = datasets.Dataset.from_dict({"image": test_images, "label": test_labels},
                                     features=datasets.Features({"image": datasets.Image(),
                                                                 "label": datasets.Array2D(shape=(23, 23), dtype="uint8")}))

# %%
train_images = glob(f"{dataset_root_path}/train/images/*.png")
train_labels = [path.replace("images", "labels").replace(".png", ".npy") for path in train_images]


train_labels = [np.load(l) for l in train_labels]
train_dataset = datasets.Dataset.from_dict({"image": train_images, "label": train_labels},
                                     features=datasets.Features({"image": datasets.Image(),
                                                                 "label": datasets.Array2D(shape=(23, 23), dtype="uint8")}))

# %%
dataset = datasets.DatasetDict({"train": train_dataset, "test": test_dataset})
print(dataset)
dataset.save_to_disk("/projects/copenlu/data/nadav/Datasets/pixel_squad_cannon/dataset")
dataset.push_to_hub("pixel_squad_cannon", token="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")
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 222844
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 11873
#     })
# })
# Saving the dataset (0/16 shards):   0%|          | 0/222844 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/11873 [00:00<?, ? examples/s]
# Pushing split train to the Hub.
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/16 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13928 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13927 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13927 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13927 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Map:   0%|          | 0/13927 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/14 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# Pushing split test to the Hub.
# Map:   0%|          | 0/11873 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/12 [00:00<?, ?ba/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
label = []
for i in range(len(dataset["train"])):
   label.append(np.max(dataset["train"][i]["label"]))

np.mean(label)
# Out:
# 0.5962736263933514
